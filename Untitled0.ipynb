# %%
# PART A ASSIGNMENT 2
# !pip install datasets
import datasets
from datasets import load_dataset
import random
from nltk import ngrams

# %%
# Load Wikipedia Simple dataset
dataset = load_dataset("wikipedia", "20220301.simple")

# Extract text data from the dataset
corpus = dataset['train']['text'][:10000]

# Create a list of all words in the corpus
words = ' '.join(corpus).split()

# Generate sentences using a unigram language model
def generate_sentence_unigram(corpus, num_words=10):
    sentence = []
    for _ in range(num_words):
        word = random.choice(corpus)
        sentence.append(word)
    return ' '.join(sentence)

# Generate and print 5 sentences
sentences = []
temp =""
for i in range(5):
  temp = generate_sentence_unigram(words)
  sentences.append(temp)
  print(f"Sentence {i + 1}: {temp}")

print("part bbbbbbbbbbbbb")

n = 2
for i in range(5):
  sentence = '<s>' +sentences[i]+'</s>'
  unigrams = ngrams(sentence.split(), n)
  print("строка \n")
  for grams in unigrams:print(grams)


print("part ccccccccccccccccc \n 4 grams")
n = 4
for i in range(5):
  sentence = '<s>' +sentences[i]+'</s>'
  unigrams = ngrams(sentence.split(), n)
  print("строка \n")
  for grams in unigrams:print(grams)


print("5 grams")
n = 5
for i in range(5):
  sentence = '<s>' +sentences[i]+'</s>'
  unigrams = ngrams(sentence.split(), n)
  print("строка \n")
  for grams in unigrams:print(grams)
# Out:
# Sentence 1: buildings, operating English Long Compound offense, Henry 2004 Midnight end
# Sentence 2: states. – - 1974 the 1985 also with 76,000 February
# Sentence 3: people. Prinz more Billy except Bosnia It Black some newspaper
# Sentence 4: is the grass Puerto in part were tabloid French can
# Sentence 5: Myanmar International them rest." the Panesar Deaths of the the
# part bbbbbbbbbbbbb
# строка
#
# ('<s>buildings,', 'operating')
# ('operating', 'English')
# ('English', 'Long')
# ('Long', 'Compound')
# ('Compound', 'offense,')
# ('offense,', 'Henry')
# ('Henry', '2004')
# ('2004', 'Midnight')
# ('Midnight', 'end</s>')
# строка
#
# ('<s>states.', '–')
# ('–', '-')
# ('-', '1974')
# ('1974', 'the')
# ('the', '1985')
# ('1985', 'also')
# ('also', 'with')
# ('with', '76,000')
# ('76,000', 'February</s>')
# строка
#
# ('<s>people.', 'Prinz')
# ('Prinz', 'more')
# ('more', 'Billy')
# ('Billy', 'except')
# ('except', 'Bosnia')
# ('Bosnia', 'It')
# ('It', 'Black')
# ('Black', 'some')
# ('some', 'newspaper</s>')
# строка
#
# ('<s>is', 'the')
# ('the', 'grass')
# ('grass', 'Puerto')
# ('Puerto', 'in')
# ('in', 'part')
# ('part', 'were')
# ('were', 'tabloid')
# ('tabloid', 'French')
# ('French', 'can</s>')
# строка
#
# ('<s>Myanmar', 'International')
# ('International', 'them')
# ('them', 'rest."')
# ('rest."', 'the')
# ('the', 'Panesar')
# ('Panesar', 'Deaths')
# ('Deaths', 'of')
# ('of', 'the')
# ('the', 'the</s>')
# part ccccccccccccccccc
#  4 grams
# строка
#
# ('<s>buildings,', 'operating', 'English', 'Long')
# ('operating', 'English', 'Long', 'Compound')
# ('English', 'Long', 'Compound', 'offense,')
# ('Long', 'Compound', 'offense,', 'Henry')
# ('Compound', 'offense,', 'Henry', '2004')
# ('offense,', 'Henry', '2004', 'Midnight')
# ('Henry', '2004', 'Midnight', 'end</s>')
# строка
#
# ('<s>states.', '–', '-', '1974')
# ('–', '-', '1974', 'the')
# ('-', '1974', 'the', '1985')
# ('1974', 'the', '1985', 'also')
# ('the', '1985', 'also', 'with')
# ('1985', 'also', 'with', '76,000')
# ('also', 'with', '76,000', 'February</s>')
# строка
#
# ('<s>people.', 'Prinz', 'more', 'Billy')
# ('Prinz', 'more', 'Billy', 'except')
# ('more', 'Billy', 'except', 'Bosnia')
# ('Billy', 'except', 'Bosnia', 'It')
# ('except', 'Bosnia', 'It', 'Black')
# ('Bosnia', 'It', 'Black', 'some')
# ('It', 'Black', 'some', 'newspaper</s>')
# строка
#
# ('<s>is', 'the', 'grass', 'Puerto')
# ('the', 'grass', 'Puerto', 'in')
# ('grass', 'Puerto', 'in', 'part')
# ('Puerto', 'in', 'part', 'were')
# ('in', 'part', 'were', 'tabloid')
# ('part', 'were', 'tabloid', 'French')
# ('were', 'tabloid', 'French', 'can</s>')
# строка
#
# ('<s>Myanmar', 'International', 'them', 'rest."')
# ('International', 'them', 'rest."', 'the')
# ('them', 'rest."', 'the', 'Panesar')
# ('rest."', 'the', 'Panesar', 'Deaths')
# ('the', 'Panesar', 'Deaths', 'of')
# ('Panesar', 'Deaths', 'of', 'the')
# ('Deaths', 'of', 'the', 'the</s>')
# 5 grams
# строка
#
# ('<s>buildings,', 'operating', 'English', 'Long', 'Compound')
# ('operating', 'English', 'Long', 'Compound', 'offense,')
# ('English', 'Long', 'Compound', 'offense,', 'Henry')
# ('Long', 'Compound', 'offense,', 'Henry', '2004')
# ('Compound', 'offense,', 'Henry', '2004', 'Midnight')
# ('offense,', 'Henry', '2004', 'Midnight', 'end</s>')
# строка
#
# ('<s>states.', '–', '-', '1974', 'the')
# ('–', '-', '1974', 'the', '1985')
# ('-', '1974', 'the', '1985', 'also')
# ('1974', 'the', '1985', 'also', 'with')
# ('the', '1985', 'also', 'with', '76,000')
# ('1985', 'also', 'with', '76,000', 'February</s>')
# строка
#
# ('<s>people.', 'Prinz', 'more', 'Billy', 'except')
# ('Prinz', 'more', 'Billy', 'except', 'Bosnia')
# ('more', 'Billy', 'except', 'Bosnia', 'It')
# ('Billy', 'except', 'Bosnia', 'It', 'Black')
# ('except', 'Bosnia', 'It', 'Black', 'some')
# ('Bosnia', 'It', 'Black', 'some', 'newspaper</s>')
# строка
#
# ('<s>is', 'the', 'grass', 'Puerto', 'in')
# ('the', 'grass', 'Puerto', 'in', 'part')
# ('grass', 'Puerto', 'in', 'part', 'were')
# ('Puerto', 'in', 'part', 'were', 'tabloid')
# ('in', 'part', 'were', 'tabloid', 'French')
# ('part', 'were', 'tabloid', 'French', 'can</s>')
# строка
#
# ('<s>Myanmar', 'International', 'them', 'rest."', 'the')
# ('International', 'them', 'rest."', 'the', 'Panesar')
# ('them', 'rest."', 'the', 'Panesar', 'Deaths')
# ('rest."', 'the', 'Panesar', 'Deaths', 'of')
# ('the', 'Panesar', 'Deaths', 'of', 'the')
# ('Panesar', 'Deaths', 'of', 'the', 'the</s>')
